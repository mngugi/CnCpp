# %%
num = int(input("Enter a number: "))

for i in range(1, 11):
    print(num, 'x', i, '=', num*i)
# Out:
# 0 x 1 = 0
# 0 x 2 = 0
# 0 x 3 = 0
# 0 x 4 = 0
# 0 x 5 = 0
# 0 x 6 = 0
# 0 x 7 = 0
# 0 x 8 = 0
# 0 x 9 = 0
# 0 x 10 = 0
